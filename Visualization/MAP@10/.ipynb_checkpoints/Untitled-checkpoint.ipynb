# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import seaborn as sns


import pandas as pd

# %%
csv = pd.read_csv('plots.csv')

# %%
csv
# Out:
#    Representation Size  R50-Rand   R50-SVD    R50-FF   R50-NRL  R50-NRL-E
# 0                    8  0.006073  0.093771  0.464590  0.464556   0.422367
# 1                   16  0.038787  0.284358  0.532455  0.532699   0.520654
# 2                   32  0.142724  0.418801  0.545814  0.547244   0.538911
# 3                   64  0.277690  0.484427  0.552802  0.554836   0.545839
# 4                  128  0.392846  0.517366  0.555656  0.558218   0.550336
# 5                  256  0.463802  0.530039  0.557220  0.559651   0.554179
# 6                  512  0.504981  0.536166  0.557844  0.560243   0.557410
# 7                 1024  0.527117  0.538637  0.559525  0.560945   0.559485
# 8                 2048  0.538737  0.538744  0.559528  0.561250   0.561159

# %%
import numpy as np

names = {
    "R50-NRL": "MRL",
    "R50-NRL-E": "MRL-E",
    "R50-FF": "Fixed Feature",
    "R50-SVD": "SVD",
    "R50-Rand": "Random Feature Selection"
}
sns.set_context('talk')
sns.set_style("white")
linestyles = ['-', '--', '-.', ':', "--", "-", ":", "-."]
markers = ['o', '^', 'v', 'h', '+', 'x', 'D', '*']

for i, ((name, mapping), linestyle, m) in enumerate(zip(names.items(), linestyles, markers)):
    print(name)
    if name == "R50-NRL":
        zorder = 30
    else:
        zorder = 2
    plt.plot(
        csv["Representation Size"], csv[name], label=mapping, marker=m, linewidth=3, linestyle=linestyle, zorder=zorder
    )

plt.xscale("log")
plt.xticks(csv["Representation Size"], csv["Representation Size"], rotation=45)
plt.xlabel("Representation Size")
plt.ylabel("MAP@10")
plt.grid()
plt.legend()

plt.savefig("MAP@10-dim-x-acc.pdf", bbox_inches="tight")
# Out:
# R50-NRL
# R50-NRL-E
# R50-FF
# R50-SVD
# R50-Rand
